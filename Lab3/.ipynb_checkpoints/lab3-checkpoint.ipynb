# %%
# !pip install beir

# %%
from beir import util, LoggingHandler

import logging
import pathlib, os

from beir.datasets.data_loader import GenericDataLoader

from sentence_transformers import SentenceTransformer

from sentence_transformers import util as sentence_transformers_util

from tqdm.notebook import tqdm

import numpy as np

import random

import faiss
SEED = 42

# %% [markdown]
# # First part
#
# Here we will carry out the first part of the project

# %%
"""
This function allows to download the dataset, it was retrieved directly from the official documentation 
"""
def download_dataset():
  #### Just some code to print debug information to stdout
  logging.basicConfig(format='%(asctime)s - %(message)s',
                      datefmt='%Y-%m-%d %H:%M:%S',
                      level=logging.INFO,
                      handlers=[LoggingHandler()])
  #### /print debug information to stdout

  #### Download scifact.zip dataset and unzip the dataset
  dataset = "dbpedia-entity"
  url = "https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/{}.zip".format(dataset)
  out_dir = os.path.join("./", "datasets")
  return util.download_and_unzip(url, out_dir)



"""
This function allows to load the dataset, it was retrieved directly from the official documentation
"""
def load_dataset(data_path):
  #### Provide the data_path where scifact has been downloaded and unzipped
  return GenericDataLoader(data_folder=data_path).load(split="test")



""" 
This function removes the rows with 0 values from the dataset representing 
the relationship between the corpora and the queries.
To do this, it uses the remove_zero_values function
"""
def remove_unrevelant(d):
    return {key: remove_zero_values(d[key]) for key in d}

def remove_zero_values(d):
    return {key: value for key, value in d.items() if value != 0}



"""
This function is used to identify texts that are related to a query
"""
def get_all_related_texts(qrels):
  texts = set()

  for v in qrels.values():
    texts.update(v)

  return texts



"""
This function is used to create the dataset requested by the instruction, 
namely a corpus consisting of all the texts having a relation with the queries as well 
as 100000 other texts

In addition to that, this function encodes directly the texts thanks to our model that we have created beforehand
"""
def get_texts_rels_and_100K_unrel(corpus, texts, model, N=100000, SEED=-1):
  if SEED != -1:
    random.seed(SEED)

  dataset = {}

  with tqdm(total=(len(texts) + N)) as pbar:

    for key in texts:
      ele = corpus.pop(key)
      dataset[key] = ele['text']
      pbar.update(1)

    for ele in random.sample(list(corpus.keys()), N):
      dataset[ele] = corpus[ele]['text']
      pbar.update(1)

  emb_values = model.encode(list(dataset.values()), normalize_embeddings=True, show_progress_bar=True)

  dataset = {key: value for key, value in zip(list(dataset.keys()), emb_values)}

  return dataset



"""
This function allows to encode the queries according to the model we have created
"""
def get_emb_queries(queries, model):
  emb_queries = {}

  with tqdm(total=(len(queries))) as pbar:
    for key, value in queries.items():
      emb_queries[key] = model.encode(value, normalize_embeddings=True)
      pbar.update(1)
  
  return emb_queries, list(queries.values())



"""
This function is used to find the average@k score which is calculated in this way:
- First, we do a dot of each query between each text and get the score
- We retrieve the k texts with the highest score
- We make the sum of the successes
- We divide by k to get the average

It uses the get_k_score function to create the k_score and the dot_product function 
to create the dot of each text for a query
"""

def get_k_average(emb_queries, emb_texts, qrels):
  rtn = {}

  with tqdm(total=(len(emb_queries))) as pbar:
    for query, query_emb in emb_queries.items():
      keys = list(emb_texts.keys())
      values = dot_product(list(emb_texts.values()), query_emb)

      dot_texts = {key: value for key, value in zip(keys, values)}

      rtn[query] = (get_k_score(dot_texts, list(qrels[query].keys())))
      pbar.update(1)


  return rtn

def get_k_score(dot_texts, rels, k=100):
  dot_lst = {key: value for key, value in sorted(dot_texts.items(), key=lambda item: item[1], reverse=True)[:k]}

  lst = list(dot_lst.keys())

  return len([x for x in rels if x in lst]) / k


def dot_product(text_embendings, query_embending):
  return [sentence_transformers_util.dot_score(query_embending, text_embending) for text_embending in text_embendings]


"""
This function does the same thing as get_k_average using the faiss library
"""
def get_k_average_faiss(emb_queries, emb_texts, qrels, top_k_hits, index):
  faiss_pred = {}

  with tqdm(total=(len(emb_queries))) as pbar:
    for query, query_emb in emb_queries.items():
      question_embedding = np.expand_dims(query_emb, axis=0)
      distances, corpus_ids = index.search(question_embedding, top_k_hits)

      hits = [{'corpus_id': id, 'score': score} for id, score in zip(corpus_ids[0], distances[0])]
      hits = sorted(hits, key=lambda x: x['score'], reverse=True)

      lst = [list(emb_texts.keys())[hit['corpus_id']] for hit in hits]

      faiss_pred[query] = len([x for x in list(qrels[query].keys()) if x in lst]) / top_k_hits

      pbar.update(1)


  return faiss_pred

# %% [markdown]
# ### Here we will download and load the datasets

# %%
data_path = download_dataset()
corpus, queries, qrels = load_dataset(data_path)
# Out:
# ./datasets/dbpedia-entity.zip:   0%|          | 0.00/610M [00:00<?, ?iB/s]
#   0%|          | 0/4635922 [00:00<?, ?it/s]

# %% [markdown]
# ### We clean the dataset of relation between queries and texts.
# ### It is a dict and here is its architecture
#
# ```
# key = queries_id
# value = dict :
#           key = text_id
#           value = number_revelant_time
# ```

# %%
qrels = remove_unrevelant(qrels)

# %% [markdown]
# ### Here we load our model, we chouge him because he his the most efficient according to the documentation

# %%
model = SentenceTransformer('msmarco-distilbert-base-tas-b')
# Out:
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/547 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %% [markdown]
# ### This function retrieves the list of relevant texts

# %%
texts = get_all_related_texts(qrels)

# %% [markdown]
# ### Here we create the dataset requested by the instruction, it contains all the texts released as well as 100000 supplementary. Moreover, we encode the text with the model we have chosen. Here is its architecture :
# ```
# key = text_id
# value = text_embended
# ```

# %%
emb_texts = get_texts_rels_and_100K_unrel(corpus.copy(), texts, model, SEED=SEED)
# Out:
#   0%|          | 0/114877 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3590 [00:00<?, ?it/s]

# %% [markdown]
# ### In the same way, we get the list of queries and the encoding with the model.

# %%
emb_queries, lst_queries = get_emb_queries(queries, model)
# Out:
#   0%|          | 0/400 [00:00<?, ?it/s]

# %% [markdown]
# ### Here we retrieve the k_average of each query
#
# This function takes a lot of time to run, ie 55 minutes on google colab, so for the sake of speed, in order to save you time, we have preprocessed this command and save the result in json format

# %%
k_average = get_k_average(emb_queries, emb_texts, qrels)

# %%
"""
import json 
with open('json_data.json') as json_file:

  k_average = json.load(json_file)
"""

# %% [markdown]
# ## As you can see here, here are the different queries with the associated k-average

# %%
k_average_labelised = {}

for key, value in k_average.items():
  tmp = queries[key]
  k_average_labelised[tmp] = value

k_average_labelised
# Out:
# {'Szechwan dish food cuisine': 0.14,
#  'roman architecture': 0.8,
#  'finland car industry manufacturer saab sisu': 0.24,
#  'france second world war normandy': 0.41,
#  'social network group selection': 0.16,
#  'D-Day normandy invasion': 0.59,
#  'web ranking scoring algorithm': 0.18,
#  'virtual museums': 0.32,
#  'Indian food': 0.87,
#  'composer museum': 0.07,
#  'gallo roman architecture in paris': 0.09,
#  'electricity source in France': 0.16,
#  'social network API': 0.2,
#  'List of films from the surrealist category': 0.08,
#  'Einstein Relativity theory': 0.5,
#  'summer flowers': 0.64,
#  'house concrete wood': 0.07,
#  'organic food advantages disadvantages': 0.14,
#  'vietnam war movie': 0.38,
#  'vietnam food recipes': 0.08,
#  'vietnamese food blog': 0.08,
#  'vietnam travel national park': 0.37,
#  'guitar chord tuning': 0.45,
#  'guitar classical flamenco': 0.5,
#  'guitar origin Russia': 0.1,
#  'guitar origin blues': 0.25,
#  'tango culture movies': 0.18,
#  'tango culture countries': 0.21,
#  'tango music  composers': 0.45,
#  'tango dance styles': 0.25,
#  'tango dance history': 0.3,
#  'bicycle sport races': 0.47,
#  'bicycle sport disciplines': 0.2,
#  'bicycle holiday towns': 0.06,
#  'bicycle holiday nature': 0.06,
#  'bicycle benefits health': 0.02,
#  'female rock singers': 0.46,
#  'south korean girl groups': 0.71,
#  'electronic music genres': 0.63,
#  'digital music notation formats': 0.24,
#  'music conferences': 0.32,
#  'intellectual property rights lobby': 0.35,
#  'Niagara falls origin lake': 0.06,
#  'Valley fever fungal infection San Joaquin': 0.02,
#  "North Dakota's lowest river of another colour": 0.11,
#  'residents small island city-state  Malay Peninsula Chinese': 0.04,
#  'John Lennon Yoko Ono album Starting Over': 0.26,
#  'John Turturro 1991 Coen Brothers film': 0.06,
#  'Baguio Quezon City  Manila official independence 1945': 0.05,
#  'daggeroso inclined to use a dagger novel Sons and Lovers': 0.03,
#  'Directed Bela Glen Glenda Bride Monster Plan 9 Outer Space': 0.04,
#  '1994 short story collection Alice Munro is Open': 0.05,
#  'Asian port state-city Sir Stamford Raffles': 0.07,
#  'Large glaciers island nation Langjokull Hofsjokull Vatnajokull': 0.14,
#  'successor James G. Blaine studied law': 0.02,
#  'Beloved author African-American Nobel Prize Literature': 0.06,
#  'Sweden Iceland currency': 0.07,
#  'Seoul Korea river name ethnic group China': 0.05,
#  'Prime minister Canada nicknamed Silver-Tongued Laurier longest unbroken term': 0.13,
#  'U.S. president authorise nuclear weapons against Japan': 0.03,
#  'Texas city Baylor University tornado 1953': 0.05,
#  'Nelson Mandela John Dube': 0.07,
#  '1997  Houston airport president': 0.05,
#  'Kennedy assassination governor of Texas seriously injured': 0.14,
#  'Alexander Nevsky Cathedral Bulgarian city liberation Turks': 0.07,
#  'country German language': 0.18,
#  'greatest guitarist': 0.32,
#  'England football player highest paid': 0.07,
#  'prima ballerina Bolshoi Theatre 1960': 0.04,
#  'Bob Ricker Executive Director the latest front group for the anti-gun movement': 0.01,
#  'most famous award winning actor singer': 0.14,
#  "mathematician computer scientist MIT's six inaugural MacVicar Faculty Fellows": 0.04,
#  'invented telescope': 0.23,
#  'most famous civic-military airports': 0.07,
#  'most beautiful railway stations world cities located': 0.24,
#  'famous historical battlefields opponents fought': 0.16,
#  'birds cannot fly': 0.02,
#  'allegedly caused World War I': 0.09,
#  'movie directors directed a block buster': 0.02,
#  'famous computer scientists disappeared at sea': 0.01,
#  'famous politicians vegetarians': 0.06,
#  'famous river confluence dam constructed': 0.11,
#  'frequently visited sharks gulf Indian Ocean': 0.09,
#  'baseball player most homeruns national league': 0.12,
#  "Noble english person from the Hundred Years' War": 0.33,
#  'State capitals of the United States of America': 0.13,
#  'National capitals situated on islands': 0.18,
#  'Nobel Prize in Literature winners who were also poets': 0.26,
#  'Formula 1 drivers that won the Monaco Grand Prix': 0.26,
#  'Formula one races in Europe': 0.37,
#  "Formula One World Constructors' Champions": 0.23,
#  'Italian nobel prize winners': 0.24,
#  'Musicians who appeared in the Blues Brothers movies': 0.17,
#  "French car models in 1960's": 0.22,
#  'Swiss cantons where they speak German': 0.4,
#  'US presidents since 1960': 0.16,
#  'Movies with eight or more Academy Awards': 0.04,
#  'FIFA world cup national team winners since 1974': 0.14,
#  'Novels that won the Booker Prize': 0.41,
#  'german female politicians': 0.73,
#  'Bond girls': 0.28,
#  'Science fiction book written in the 1980': 0.28,
#  'Star Trek Captains': 0.33,
#  'living nordic classical composers': 0.31,
#  'EU countries': 0.24,
#  'record-breaking sprinters in male 100-meter sprints': 0.15,
#  'professional baseball team in Japan': 0.33,
#  'Japanese players in Major League Baseball': 0.4,
#  'National Parks East Coast Canada US': 0.21,
#  'Films directed by Akira Kurosawa': 0.29,
#  'Airports in Germany': 0.66,
#  'Universities in Catalunya': 0.2,
#  'Hanseatic league in Germany in the Netherlands Circle': 0.05,
#  'chess world champions': 0.68,
#  'Chemical elements that are named after people': 0.14,
#  'olympic classes dinghy sailing': 0.26,
#  'Neil Gaiman novels': 0.33,
#  'Hugo awarded best novels': 0.45,
#  'Alan Moore graphic novels adapted to film': 0.17,
#  'Pacific navigators Australia explorers': 0.18,
#  'Ferris and observation wheels': 0.45,
#  'films shot in Venice': 0.12,
#  'circus mammals': 0.05,
#  'Works by Charles Rennie Mackintosh': 0.1,
#  'Movies about English hooligans': 0.11,
#  'List of countries in World War Two': 0.17,
#  'Axis powers of World War II': 0.33,
#  "Nordic authors who are known for children's literature": 0.33,
#  'Paul Auster novels': 0.2,
#  'Hybrid cars sold in Europe': 0.23,
#  'Tom Hanks movies where he plays a leading role.': 0.27,
#  'Pure object-oriented programing languages': 0.58,
#  'Makers of lawn tennis rackets': 0.13,
#  'Computer systems that have a recursive acronym for the name': 0.11,
#  'Which German cities have more than 250000 inhabitants?': 0.25,
#  'Who produces Orangina?': 0.02,
#  'Who is the Formula 1 race driver with the most races?': 0.03,
#  'Give me all world heritage sites designated within the past five years.': 0.26,
#  'Who is the youngest player in the Premier League?': 0.12,
#  'Give me all members of Prodigy.': 0.12,
#  'Give me all cars that are produced in Germany.': 0.65,
#  'Who was the successor of John F. Kennedy?': 0.03,
#  'What is the capital of Canada?': 0.03,
#  'Who is the governor of Texas?': 0.31,
#  'Who was the father of Queen Elizabeth II?': 0.06,
#  'Which U.S. state has been admitted latest?': 0.05,
#  'Sean Parnell is the governor of which U.S. state?': 0.03,
#  'Give me all movies directed by Francis Ford Coppola.': 0.2,
#  'Who is the mayor of Berlin?': 0.14,
#  'Give me all current Methodist national leaders.': 0.05,
#  'Give me all Australian nonprofit organizations.': 0.34,
#  'Who developed Skype?': 0.07,
#  'Give me all companies in Munich.': 0.62,
#  'List all boardgames by GMT.': 0.13,
#  'Who is the husband of Amanda Palmer?': 0.01,
#  'Give me all breeds of the German Shepherd dog.': 0.18,
#  'Which cities does the Weser flow through?': 0.15,
#  'Which countries are connected by the Rhine?': 0.1,
#  'Which professional surfers were born on the Philippines?': 0.0,
#  'In which UK city are the headquarters of the MI6?': 0.01,
#  'Which other weapons did the designer of the Uzi develop?': 0.02,
#  'What is the second highest mountain on Earth?': 0.09,
#  'Give me all Frisian islands that belong to the Netherlands.': 0.22,
#  'What is the ruling party in Lisbon?': 0.01,
#  'Which Greek goddesses dwelt on Mount Olympus?': 0.25,
#  'Give me the Apollo 14 astronauts.': 0.06,
#  'What is the time zone of Salt Lake City?': 0.04,
#  'Which U.S. states are in the same timezone as Utah?': 0.04,
#  'Give me all professional skateboarders from Sweden.': 0.04,
#  'Give me a list of all lakes in Denmark.': 0.17,
#  'Give me all Argentine films.': 0.98,
#  'Give me all launch pads operated by NASA.': 0.27,
#  'Which instruments did John Lennon play?': 0.06,
#  'Which ships were called after Benjamin Franklin?': 0.1,
#  'Who are the parents of the wife of Juan Carlos I?': 0.03,
#  'In which U.S. state is Area 51 located?': 0.02,
#  'Which daughters of British earls died in the same place they were born in?': 0.02,
#  'List the children of Margaret Thatcher.': 0.04,
#  'Who was called Scarface?': 0.1,
#  'To which countries does the Himalayan mountain system extend?': 0.18,
#  'Give me all books by William Goldman with more than 300 pages.': 0.14,
#  'Which books by Kerouac were published by Viking Press?': 0.03,
#  'Give me a list of all American inventions.': 0.1,
#  'Who created the comic Captain America?': 0.12,
#  'Which films starring Clint Eastwood did he direct himself?': 0.28,
#  'In which city was the former Dutch queen Juliana buried?': 0.01,
#  'Give me a list of all trumpet players that were bandleaders.': 0.23,
#  'Where is the residence of the prime minister of Spain?': 0.02,
#  'Which U.S. State has the abbreviation MN?': 0.32,
#  'Show me all songs from Bruce Springsteen released between 1980 and 1990.': 0.35,
#  'Which movies did Sam Raimi direct after Army of Darkness?': 0.06,
#  'Who wrote the lyrics for the Polish national anthem?': 0.03,
#  'Who painted The Storm on the Sea of Galilee?': 0.03,
#  'Which country does the creator of Miffy come from?': 0.02,
#  'For which label did Elvis record his first album?': 0.09,
#  'Give me all female Russian astronauts.': 0.13,
#  'In which country does the Nile start?': 0.06,
#  'Which countries have places with more than two caves?': 0.05,
#  'Which classis does the Millepede belong to?': 0.01,
#  'Who created Goofy?': 0.11,
#  'Give me the capitals of all countries in Africa.': 0.09,
#  'Give me all cities in New Jersey with more than 100000 inhabitants.': 0.08,
#  'Which museum exhibits The Scream by Munch?': 0.0,
#  'Which states border Illinois?': 0.08,
#  'Which mountain is the highest after the Annapurna?': 0.1,
#  'In which films directed by Garry Marshall was Julia Roberts starring?': 0.04,
#  'Which bridges are of the same type as the Manhattan Bridge?': 0.36,
#  'Which European countries have a constitutional monarchy?': 0.2,
#  'Which awards did WikiLeaks win?': 0.01,
#  'Who is the daughter of Bill Clinton married to?': 0.02,
#  'Which state of the USA has the highest population density?': 0.05,
#  'What is the currency of the Czech Republic?': 0.05,
#  'Which countries in the European Union adopted the Euro?': 0.21,
#  'Which countries have more than two official languages?': 0.08,
#  'Who is the owner of Universal Studios?': 0.02,
#  'Through which countries does the Yenisei river flow?': 0.04,
#  'Which monarchs of the United Kingdom were married to a German?': 0.04,
#  'Which river does the Brooklyn Bridge cross?': 0.05,
#  'What is the highest mountain in Australia?': 0.11,
#  'Give me all soccer clubs in Spain.': 0.72,
#  'What are the official languages of the Philippines?': 0.19,
#  'Who is the mayor of New York City?': 0.21,
#  'Which telecommunications organizations are located in Belgium?': 0.13,
#  'What is the highest place of Karakoram?': 0.25,
#  'Give me all companies in the advertising industry.': 0.74,
#  'What did Bruce Carver die from?': 0.01,
#  'Give me all school types.': 0.72,
#  'Which presidents were born in 1945?': 0.0,
#  'Give me all presidents of the United States.': 0.24,
#  'Who was the wife of U.S. president Lincoln?': 0.03,
#  'Who developed the video game World of Warcraft?': 0.11,
#  'List all episodes of the first season of the HBO television series The Sopranos!': 0.25,
#  'Who produced the most films?': 0.01,
#  'Give me all people with first name Jimmy.': 0.98,
#  'Where did Abraham Lincoln die?': 0.09,
#  'Which mountains are higher than the Nanga Parbat?': 0.11,
#  'Who created Wikipedia?': 0.03,
#  'Which software has been developed by organizations founded in California?': 0.26,
#  'Which companies work in the aerospace industry as well as on nuclear reactor technology?': 0.16,
#  'Which actors were born in Germany?': 0.63,
#  'Which caves have more than 3 entrances?': 0.24,
#  'Give me all films produced by Hal Roach.': 0.74,
#  'Give me all video games published by Mean Hamster Software.': 0.03,
#  'Which capitals in Europe were host cities of the summer olympic games?': 0.17,
#  'Who has been the 5th president of the United States of America?': 0.04,
#  'Which music albums contain the song Last Christmas?': 0.08,
#  'Give me all books written by Danielle Steel.': 0.51,
#  'Which airports are located in California, USA?': 0.83,
#  'Which states of Germany are governed by the Social Democratic Party?': 0.1,
#  'Give me all Canadian Grunge record labels.': 0.02,
#  'Which country has the most official languages?': 0.15,
#  'In which programming language is GIMP written?': 0.04,
#  'Who produced films starring Natalie Portman?': 0.21,
#  'Give me all movies with Tom Cruise.': 0.27,
#  'In which films did Julia Roberts as well as Richard Gere play?': 0.03,
#  'Who wrote the book The pillars of the Earth?': 0.02,
#  'Give me all soccer clubs in the Premier League.': 0.82,
#  'Which U.S. states possess gold minerals?': 0.12,
#  'Which organizations were founded in 1950?': 0.17,
#  '44 magnum hunting': 0.13,
#  'asheville north carolina': 0.29,
#  'YMCA Tampa': 0.05,
#  'ashley wagner': 0.01,
#  'beach flowers': 0.13,
#  'bourbonnais il': 0.04,
#  'chase masterson': 0.02,
#  'concord steel': 0.01,
#  'danielia cotton': 0.01,
#  'austin powers': 0.19,
#  'eagle rock, ca': 0.06,
#  'glenn frey': 0.27,
#  'goodwill of michigan': 0.02,
#  'iowa energy': 0.09,
#  'john elliott': 0.26,
#  'lawrence general hospital': 0.04,
#  'michael zimmerman': 0.04,
#  'motorola bluetooth hs850': 0.04,
#  'nokia e73': 0.06,
#  'palm tungsten e2 handheld': 0.03,
#  'philadelphia neufchatel cheese': 0.02,
#  'pizza populous detroit mi': 0.01,
#  'banana paper making': 0.01,
#  'plymouth police department': 0.04,
#  'sealy mattress co': 0.03,
#  'spring shoes canada': 0.01,
#  'sri lanka government gazette': 0.05,
#  'the big texan steak house': 0.05,
#  'ben franklin': 0.2,
#  'bradley center': 0.01,
#  'brooklyn bridge': 0.14,
#  'butte montana': 0.12,
#  'canasta cards': 0.05,
#  'carl lewis': 0.02,
#  'B. F. Skinner': 0.06,
#  'carolina': 0.24,
#  'charles darwin': 0.32,
#  'city of virginia beach': 0.27,
#  'coastal carolina': 0.28,
#  'david suchet': 0.01,
#  'disney orlando': 0.14,
#  'ellis college': 0.01,
#  'Bookwork': 0.02,
#  'eloan line of credit': 0.02,
#  'fitzgerald auto mall chambersburg pa': 0.01,
#  'harry potter': 0.55,
#  'imdb batman returns': 0.07,
#  'jack the ripper': 0.27,
#  'james caldwell high school': 0.03,
#  'NAACP Image Awards': 0.43,
#  'joan of arc': 0.36,
#  'keith urban': 0.31,
#  'king arthur': 0.26,
#  'laura bush': 0.1,
#  'Scott County': 0.28,
#  'laura steele bob and tom': 0.02,
#  'lincoln park': 0.35,
#  'mario bros': 0.31,
#  'mason ohio': 0.03,
#  'mercy hospital in des moines, ia': 0.03,
#  'air wisconsin': 0.07,
#  'michael douglas': 0.1,
#  'mr rourke fantasy island': 0.02,
#  'airsoft glock': 0.08,
#  'richmond virginia': 0.45,
#  'rock 103 memphis': 0.01,
#  'sacred heart u': 0.14,
#  'sagemont church houston tx': 0.01,
#  'san antonio': 0.53,
#  'savannah tech': 0.04,
#  'sharp pc': 0.16,
#  'sonny and cher': 0.38,
#  'st lucia': 0.43,
#  'st paul saints': 0.1,
#  'the dish danielle fishel': 0.02,
#  'the longest yard sale': 0.02,
#  'the morning call lehigh valley pa': 0.03,
#  'thomas jefferson': 0.38,
#  'university of north dakota': 0.27,
#  'american embassy nairobi': 0.04,
#  'university of phoenix': 0.04,
#  'westminster abbey': 0.21,
#  'MADRID': 0.35,
#  'New England Coffee': 0.06,
#  'PINK PANTHER 2': 0.24,
#  'University of Texas at Austin': 0.33,
#  'Apollo astronauts who walked on the Moon': 0.24,
#  'did nicole kidman have any siblings': 0.02,
#  'dioceses of the church of ireland': 0.41,
#  'first targets of the atomic bomb': 0.2,
#  'five great epics of Tamil literature': 0.19,
#  'gods who dwelt on Mount Olympus': 0.18,
#  'hijackers in the September 11 attacks': 0.38,
#  'john lennon, parents': 0.03,
#  'Arab states of the Persian Gulf': 0.26,
#  'kublai khan siblings': 0.09,
#  'lilly allen parents': 0.01,
#  'major leagues in the united states': 0.41,
#  'matt berry tv series': 0.06,
#  'members of u2?': 0.1,
#  'movies starring erykah badu': 0.03,
#  'nations where Portuguese is an official language': 0.21,
#  'astronauts who landed on the Moon': 0.16,
#  "orders (or 'choirs') of angels": 0.05,
#  'permanent members of the UN Security Council': 0.21,
#  'presidents depicted on mount rushmore who died of shooting': 0.03,
#  'provinces and territories of Canada': 0.45,
#  'ratt albums': 0.23,
#  'republics of the former Yugoslavia': 0.32,
#  'revolutionaries of 1959 in Cuba': 0.28,
#  'standard axioms of set theory': 0.32,
#  'states that border oklahoma': 0.07,
#  'ten ancient Greek city-kingdoms of Cyprus': 0.23,
#  'the four of the companions of the prophet': 0.12,
#  'twelve tribes or sons of Israel': 0.27,
#  'what books did paul of tarsus write?': 0.01,
#  'what languages do they speak in afghanistan': 0.17,
#  'where the British monarch is also head of state': 0.14,
#  'who invented the python programming language': 0.09,
#  'wonders of the ancient world': 0.15,
#  'boroughs of New York City': 0.17,
#  'Branches of the US military': 0.33,
#  'continents in the world': 0.16,
#  'degrees of Eastern Orthodox monasticism': 0.1,
#  'Carriers that Blackberry makes phones for.': 0.26,
#  'Campuses of Indiana University.': 0.24,
#  'Donors to the Home Depot Foundation.': 0.03,
#  'Airlines that Air Canada has code share flights with.': 0.14,
#  'Authors awarded an Anthony Award at Bouchercon in 2007.': 0.09,
#  'Universities that are members of the SEC conference for football.': 0.24,
#  'Sponsors of the Mancuso quilt festivals.': 0.0,
#  'Members of the band Jefferson Airplane.': 0.26,
#  'Companies that John Hennessey serves on the board of.': 0.01,
#  'Winners of the ACM Athena award.': 0.0,
#  'Scotch whisky distilleries on the island of Islay.': 0.22,
#  'Professional sports teams in Philadelphia.': 0.32,
#  'Products of Medimmune, Inc.': 0.12,
#  'Organizations that award Nobel prizes.': 0.24,
#  'Airlines that currently use Boeing 747 planes.': 0.21,
#  'Members of The Beaux Arts Trio.': 0.06}

# %% [markdown]
# # Second part

# %% [markdown]
# Here we use the faiss library to make our recommendations:<br>
# We use 1024 clusters because it is an optimized value for the GPU<br>
# We use as metric the inner_product because once normalized, it corresponds to the same thing as a cosine similarity.

# %%
n_clusters = 1024
embedding_size = len(list(emb_texts.values())[0])
top_k_hits = 100
quantizer = faiss.IndexFlatIP(embedding_size)
index = faiss.IndexIVFFlat(quantizer, embedding_size, n_clusters, faiss.METRIC_INNER_PRODUCT)
index.nprobe = 3

index.train(np.array(list(emb_texts.values())))

index.add(np.array(list(emb_texts.values())))

# %%
faiss_pred = get_k_average_faiss(emb_queries, emb_texts, qrels, top_k_hits, index)

# %%
k_average_faiss_labelised = {}

for key, value in faiss_pred.items():
  tmp = queries[key]
  k_average_faiss_labelised[tmp] = value

k_average_faiss_labelised
# Out:
# {'Szechwan dish food cuisine': 0.19,
#  'roman architecture': 0.76,
#  'finland car industry manufacturer saab sisu': 0.15,
#  'france second world war normandy': 0.49,
#  'social network group selection': 0.08,
#  'D-Day normandy invasion': 0.47,
#  'web ranking scoring algorithm': 0.1,
#  'virtual museums': 0.32,
#  'Indian food': 0.88,
#  'composer museum': 0.07,
#  'gallo roman architecture in paris': 0.06,
#  'electricity source in France': 0.16,
#  'social network API': 0.17,
#  'List of films from the surrealist category': 0.07,
#  'Einstein Relativity theory': 0.42,
#  'summer flowers': 0.57,
#  'house concrete wood': 0.07,
#  'organic food advantages disadvantages': 0.08,
#  'vietnam war movie': 0.28,
#  'vietnam food recipes': 0.06,
#  'vietnamese food blog': 0.06,
#  'vietnam travel national park': 0.37,
#  'guitar chord tuning': 0.45,
#  'guitar classical flamenco': 0.42,
#  'guitar origin Russia': 0.03,
#  'guitar origin blues': 0.22,
#  'tango culture movies': 0.12,
#  'tango culture countries': 0.17,
#  'tango music  composers': 0.47,
#  'tango dance styles': 0.24,
#  'tango dance history': 0.29,
#  'bicycle sport races': 0.49,
#  'bicycle sport disciplines': 0.19,
#  'bicycle holiday towns': 0.04,
#  'bicycle holiday nature': 0.05,
#  'bicycle benefits health': 0.02,
#  'female rock singers': 0.55,
#  'south korean girl groups': 0.76,
#  'electronic music genres': 0.65,
#  'digital music notation formats': 0.13,
#  'music conferences': 0.26,
#  'intellectual property rights lobby': 0.09,
#  'Niagara falls origin lake': 0.01,
#  'Valley fever fungal infection San Joaquin': 0.02,
#  "North Dakota's lowest river of another colour": 0.1,
#  'residents small island city-state  Malay Peninsula Chinese': 0.03,
#  'John Lennon Yoko Ono album Starting Over': 0.19,
#  'John Turturro 1991 Coen Brothers film': 0.0,
#  'Baguio Quezon City  Manila official independence 1945': 0.03,
#  'daggeroso inclined to use a dagger novel Sons and Lovers': 0.01,
#  'Directed Bela Glen Glenda Bride Monster Plan 9 Outer Space': 0.02,
#  '1994 short story collection Alice Munro is Open': 0.04,
#  'Asian port state-city Sir Stamford Raffles': 0.05,
#  'Large glaciers island nation Langjokull Hofsjokull Vatnajokull': 0.05,
#  'successor James G. Blaine studied law': 0.01,
#  'Beloved author African-American Nobel Prize Literature': 0.01,
#  'Sweden Iceland currency': 0.04,
#  'Seoul Korea river name ethnic group China': 0.05,
#  'Prime minister Canada nicknamed Silver-Tongued Laurier longest unbroken term': 0.07,
#  'U.S. president authorise nuclear weapons against Japan': 0.02,
#  'Texas city Baylor University tornado 1953': 0.03,
#  'Nelson Mandela John Dube': 0.01,
#  '1997  Houston airport president': 0.03,
#  'Kennedy assassination governor of Texas seriously injured': 0.06,
#  'Alexander Nevsky Cathedral Bulgarian city liberation Turks': 0.07,
#  'country German language': 0.17,
#  'greatest guitarist': 0.3,
#  'England football player highest paid': 0.04,
#  'prima ballerina Bolshoi Theatre 1960': 0.0,
#  'Bob Ricker Executive Director the latest front group for the anti-gun movement': 0.0,
#  'most famous award winning actor singer': 0.07,
#  "mathematician computer scientist MIT's six inaugural MacVicar Faculty Fellows": 0.04,
#  'invented telescope': 0.13,
#  'most famous civic-military airports': 0.05,
#  'most beautiful railway stations world cities located': 0.22,
#  'famous historical battlefields opponents fought': 0.2,
#  'birds cannot fly': 0.01,
#  'allegedly caused World War I': 0.09,
#  'movie directors directed a block buster': 0.01,
#  'famous computer scientists disappeared at sea': 0.01,
#  'famous politicians vegetarians': 0.03,
#  'famous river confluence dam constructed': 0.1,
#  'frequently visited sharks gulf Indian Ocean': 0.08,
#  'baseball player most homeruns national league': 0.08,
#  "Noble english person from the Hundred Years' War": 0.31,
#  'State capitals of the United States of America': 0.02,
#  'National capitals situated on islands': 0.16,
#  'Nobel Prize in Literature winners who were also poets': 0.13,
#  'Formula 1 drivers that won the Monaco Grand Prix': 0.25,
#  'Formula one races in Europe': 0.37,
#  "Formula One World Constructors' Champions": 0.22,
#  'Italian nobel prize winners': 0.14,
#  'Musicians who appeared in the Blues Brothers movies': 0.12,
#  "French car models in 1960's": 0.24,
#  'Swiss cantons where they speak German': 0.4,
#  'US presidents since 1960': 0.16,
#  'Movies with eight or more Academy Awards': 0.04,
#  'FIFA world cup national team winners since 1974': 0.12,
#  'Novels that won the Booker Prize': 0.43,
#  'german female politicians': 0.81,
#  'Bond girls': 0.31,
#  'Science fiction book written in the 1980': 0.3,
#  'Star Trek Captains': 0.33,
#  'living nordic classical composers': 0.36,
#  'EU countries': 0.13,
#  'record-breaking sprinters in male 100-meter sprints': 0.17,
#  'professional baseball team in Japan': 0.34,
#  'Japanese players in Major League Baseball': 0.42,
#  'National Parks East Coast Canada US': 0.14,
#  'Films directed by Akira Kurosawa': 0.31,
#  'Airports in Germany': 0.66,
#  'Universities in Catalunya': 0.18,
#  'Hanseatic league in Germany in the Netherlands Circle': 0.0,
#  'chess world champions': 0.67,
#  'Chemical elements that are named after people': 0.18,
#  'olympic classes dinghy sailing': 0.26,
#  'Neil Gaiman novels': 0.15,
#  'Hugo awarded best novels': 0.46,
#  'Alan Moore graphic novels adapted to film': 0.12,
#  'Pacific navigators Australia explorers': 0.18,
#  'Ferris and observation wheels': 0.45,
#  'films shot in Venice': 0.08,
#  'circus mammals': 0.06,
#  'Works by Charles Rennie Mackintosh': 0.0,
#  'Movies about English hooligans': 0.07,
#  'List of countries in World War Two': 0.18,
#  'Axis powers of World War II': 0.28,
#  "Nordic authors who are known for children's literature": 0.33,
#  'Paul Auster novels': 0.19,
#  'Hybrid cars sold in Europe': 0.21,
#  'Tom Hanks movies where he plays a leading role.': 0.21,
#  'Pure object-oriented programing languages': 0.61,
#  'Makers of lawn tennis rackets': 0.1,
#  'Computer systems that have a recursive acronym for the name': 0.07,
#  'Which German cities have more than 250000 inhabitants?': 0.26,
#  'Who produces Orangina?': 0.01,
#  'Who is the Formula 1 race driver with the most races?': 0.04,
#  'Give me all world heritage sites designated within the past five years.': 0.26,
#  'Who is the youngest player in the Premier League?': 0.06,
#  'Give me all members of Prodigy.': 0.01,
#  'Give me all cars that are produced in Germany.': 0.92,
#  'Who was the successor of John F. Kennedy?': 0.02,
#  'What is the capital of Canada?': 0.03,
#  'Who is the governor of Texas?': 0.26,
#  'Who was the father of Queen Elizabeth II?': 0.03,
#  'Which U.S. state has been admitted latest?': 0.02,
#  'Sean Parnell is the governor of which U.S. state?': 0.0,
#  'Give me all movies directed by Francis Ford Coppola.': 0.16,
#  'Who is the mayor of Berlin?': 0.1,
#  'Give me all current Methodist national leaders.': 0.03,
#  'Give me all Australian nonprofit organizations.': 0.2,
#  'Who developed Skype?': 0.0,
#  'Give me all companies in Munich.': 0.48,
#  'List all boardgames by GMT.': 0.13,
#  'Who is the husband of Amanda Palmer?': 0.01,
#  'Give me all breeds of the German Shepherd dog.': 0.14,
#  'Which cities does the Weser flow through?': 0.1,
#  'Which countries are connected by the Rhine?': 0.04,
#  'Which professional surfers were born on the Philippines?': 0.0,
#  'In which UK city are the headquarters of the MI6?': 0.01,
#  'Which other weapons did the designer of the Uzi develop?': 0.03,
#  'What is the second highest mountain on Earth?': 0.06,
#  'Give me all Frisian islands that belong to the Netherlands.': 0.22,
#  'What is the ruling party in Lisbon?': 0.01,
#  'Which Greek goddesses dwelt on Mount Olympus?': 0.24,
#  'Give me the Apollo 14 astronauts.': 0.07,
#  'What is the time zone of Salt Lake City?': 0.0,
#  'Which U.S. states are in the same timezone as Utah?': 0.01,
#  'Give me all professional skateboarders from Sweden.': 0.0,
#  'Give me a list of all lakes in Denmark.': 0.16,
#  'Give me all Argentine films.': 0.99,
#  'Give me all launch pads operated by NASA.': 0.32,
#  'Which instruments did John Lennon play?': 0.01,
#  'Which ships were called after Benjamin Franklin?': 0.09,
#  'Who are the parents of the wife of Juan Carlos I?': 0.03,
#  'In which U.S. state is Area 51 located?': 0.0,
#  'Which daughters of British earls died in the same place they were born in?': 0.01,
#  'List the children of Margaret Thatcher.': 0.01,
#  'Who was called Scarface?': 0.04,
#  'To which countries does the Himalayan mountain system extend?': 0.16,
#  'Give me all books by William Goldman with more than 300 pages.': 0.11,
#  'Which books by Kerouac were published by Viking Press?': 0.03,
#  'Give me a list of all American inventions.': 0.06,
#  'Who created the comic Captain America?': 0.1,
#  'Which films starring Clint Eastwood did he direct himself?': 0.29,
#  'In which city was the former Dutch queen Juliana buried?': 0.0,
#  'Give me a list of all trumpet players that were bandleaders.': 0.29,
#  'Where is the residence of the prime minister of Spain?': 0.02,
#  'Which U.S. State has the abbreviation MN?': 0.12,
#  'Show me all songs from Bruce Springsteen released between 1980 and 1990.': 0.32,
#  'Which movies did Sam Raimi direct after Army of Darkness?': 0.06,
#  'Who wrote the lyrics for the Polish national anthem?': 0.02,
#  'Who painted The Storm on the Sea of Galilee?': 0.03,
#  'Which country does the creator of Miffy come from?': 0.01,
#  'For which label did Elvis record his first album?': 0.08,
#  'Give me all female Russian astronauts.': 0.11,
#  'In which country does the Nile start?': 0.01,
#  'Which countries have places with more than two caves?': 0.0,
#  'Which classis does the Millepede belong to?': 0.01,
#  'Who created Goofy?': 0.09,
#  'Give me the capitals of all countries in Africa.': 0.04,
#  'Give me all cities in New Jersey with more than 100000 inhabitants.': 0.07,
#  'Which museum exhibits The Scream by Munch?': 0.01,
#  'Which states border Illinois?': 0.06,
#  'Which mountain is the highest after the Annapurna?': 0.08,
#  'In which films directed by Garry Marshall was Julia Roberts starring?': 0.04,
#  'Which bridges are of the same type as the Manhattan Bridge?': 0.47,
#  'Which European countries have a constitutional monarchy?': 0.1,
#  'Which awards did WikiLeaks win?': 0.01,
#  'Who is the daughter of Bill Clinton married to?': 0.01,
#  'Which state of the USA has the highest population density?': 0.04,
#  'What is the currency of the Czech Republic?': 0.05,
#  'Which countries in the European Union adopted the Euro?': 0.2,
#  'Which countries have more than two official languages?': 0.08,
#  'Who is the owner of Universal Studios?': 0.01,
#  'Through which countries does the Yenisei river flow?': 0.04,
#  'Which monarchs of the United Kingdom were married to a German?': 0.03,
#  'Which river does the Brooklyn Bridge cross?': 0.03,
#  'What is the highest mountain in Australia?': 0.11,
#  'Give me all soccer clubs in Spain.': 0.84,
#  'What are the official languages of the Philippines?': 0.17,
#  'Who is the mayor of New York City?': 0.15,
#  'Which telecommunications organizations are located in Belgium?': 0.12,
#  'What is the highest place of Karakoram?': 0.26,
#  'Give me all companies in the advertising industry.': 0.92,
#  'What did Bruce Carver die from?': 0.0,
#  'Give me all school types.': 0.8,
#  'Which presidents were born in 1945?': 0.0,
#  'Give me all presidents of the United States.': 0.43,
#  'Who was the wife of U.S. president Lincoln?': 0.01,
#  'Who developed the video game World of Warcraft?': 0.12,
#  'List all episodes of the first season of the HBO television series The Sopranos!': 0.24,
#  'Who produced the most films?': 0.01,
#  'Give me all people with first name Jimmy.': 0.96,
#  'Where did Abraham Lincoln die?': 0.06,
#  'Which mountains are higher than the Nanga Parbat?': 0.12,
#  'Who created Wikipedia?': 0.02,
#  'Which software has been developed by organizations founded in California?': 0.18,
#  'Which companies work in the aerospace industry as well as on nuclear reactor technology?': 0.12,
#  'Which actors were born in Germany?': 0.68,
#  'Which caves have more than 3 entrances?': 0.13,
#  'Give me all films produced by Hal Roach.': 0.35,
#  'Give me all video games published by Mean Hamster Software.': 0.02,
#  'Which capitals in Europe were host cities of the summer olympic games?': 0.16,
#  'Who has been the 5th president of the United States of America?': 0.0,
#  'Which music albums contain the song Last Christmas?': 0.09,
#  'Give me all books written by Danielle Steel.': 0.53,
#  'Which airports are located in California, USA?': 0.92,
#  'Which states of Germany are governed by the Social Democratic Party?': 0.07,
#  'Give me all Canadian Grunge record labels.': 0.02,
#  'Which country has the most official languages?': 0.15,
#  'In which programming language is GIMP written?': 0.04,
#  'Who produced films starring Natalie Portman?': 0.1,
#  'Give me all movies with Tom Cruise.': 0.25,
#  'In which films did Julia Roberts as well as Richard Gere play?': 0.03,
#  'Who wrote the book The pillars of the Earth?': 0.01,
#  'Give me all soccer clubs in the Premier League.': 0.87,
#  'Which U.S. states possess gold minerals?': 0.08,
#  'Which organizations were founded in 1950?': 0.19,
#  '44 magnum hunting': 0.11,
#  'asheville north carolina': 0.08,
#  'YMCA Tampa': 0.02,
#  'ashley wagner': 0.0,
#  'beach flowers': 0.1,
#  'bourbonnais il': 0.0,
#  'chase masterson': 0.0,
#  'concord steel': 0.0,
#  'danielia cotton': 0.0,
#  'austin powers': 0.1,
#  'eagle rock, ca': 0.03,
#  'glenn frey': 0.0,
#  'goodwill of michigan': 0.0,
#  'iowa energy': 0.06,
#  'john elliott': 0.03,
#  'lawrence general hospital': 0.03,
#  'michael zimmerman': 0.0,
#  'motorola bluetooth hs850': 0.03,
#  'nokia e73': 0.03,
#  'palm tungsten e2 handheld': 0.01,
#  'philadelphia neufchatel cheese': 0.0,
#  'pizza populous detroit mi': 0.0,
#  'banana paper making': 0.01,
#  'plymouth police department': 0.04,
#  'sealy mattress co': 0.02,
#  'spring shoes canada': 0.01,
#  'sri lanka government gazette': 0.03,
#  'the big texan steak house': 0.03,
#  'ben franklin': 0.01,
#  'bradley center': 0.0,
#  'brooklyn bridge': 0.05,
#  'butte montana': 0.02,
#  'canasta cards': 0.04,
#  'carl lewis': 0.0,
#  'B. F. Skinner': 0.01,
#  'carolina': 0.12,
#  'charles darwin': 0.28,
#  'city of virginia beach': 0.12,
#  'coastal carolina': 0.04,
#  'david suchet': 0.0,
#  'disney orlando': 0.03,
#  'ellis college': 0.01,
#  'Bookwork': 0.01,
#  'eloan line of credit': 0.04,
#  'fitzgerald auto mall chambersburg pa': 0.0,
#  'harry potter': 0.51,
#  'imdb batman returns': 0.03,
#  'jack the ripper': 0.13,
#  'james caldwell high school': 0.02,
#  'NAACP Image Awards': 0.42,
#  'joan of arc': 0.03,
#  'keith urban': 0.01,
#  'king arthur': 0.04,
#  'laura bush': 0.03,
#  'Scott County': 0.06,
#  'laura steele bob and tom': 0.0,
#  'lincoln park': 0.17,
#  'mario bros': 0.31,
#  'mason ohio': 0.02,
#  'mercy hospital in des moines, ia': 0.03,
#  'air wisconsin': 0.02,
#  'michael douglas': 0.02,
#  'mr rourke fantasy island': 0.0,
#  'airsoft glock': 0.05,
#  'richmond virginia': 0.22,
#  'rock 103 memphis': 0.0,
#  'sacred heart u': 0.11,
#  'sagemont church houston tx': 0.0,
#  'san antonio': 0.22,
#  'savannah tech': 0.03,
#  'sharp pc': 0.15,
#  'sonny and cher': 0.34,
#  'st lucia': 0.16,
#  'st paul saints': 0.02,
#  'the dish danielle fishel': 0.0,
#  'the longest yard sale': 0.0,
#  'the morning call lehigh valley pa': 0.01,
#  'thomas jefferson': 0.13,
#  'university of north dakota': 0.21,
#  'american embassy nairobi': 0.02,
#  'university of phoenix': 0.02,
#  'westminster abbey': 0.1,
#  'MADRID': 0.09,
#  'New England Coffee': 0.02,
#  'PINK PANTHER 2': 0.13,
#  'University of Texas at Austin': 0.21,
#  'Apollo astronauts who walked on the Moon': 0.25,
#  'did nicole kidman have any siblings': 0.0,
#  'dioceses of the church of ireland': 0.38,
#  'first targets of the atomic bomb': 0.04,
#  'five great epics of Tamil literature': 0.2,
#  'gods who dwelt on Mount Olympus': 0.19,
#  'hijackers in the September 11 attacks': 0.33,
#  'john lennon, parents': 0.01,
#  'Arab states of the Persian Gulf': 0.25,
#  'kublai khan siblings': 0.06,
#  'lilly allen parents': 0.0,
#  'major leagues in the united states': 0.38,
#  'matt berry tv series': 0.03,
#  'members of u2?': 0.02,
#  'movies starring erykah badu': 0.0,
#  'nations where Portuguese is an official language': 0.16,
#  'astronauts who landed on the Moon': 0.17,
#  "orders (or 'choirs') of angels": 0.02,
#  'permanent members of the UN Security Council': 0.1,
#  'presidents depicted on mount rushmore who died of shooting': 0.02,
#  'provinces and territories of Canada': 0.24,
#  'ratt albums': 0.11,
#  'republics of the former Yugoslavia': 0.28,
#  'revolutionaries of 1959 in Cuba': 0.28,
#  'standard axioms of set theory': 0.33,
#  'states that border oklahoma': 0.03,
#  'ten ancient Greek city-kingdoms of Cyprus': 0.21,
#  'the four of the companions of the prophet': 0.13,
#  'twelve tribes or sons of Israel': 0.27,
#  'what books did paul of tarsus write?': 0.0,
#  'what languages do they speak in afghanistan': 0.13,
#  'where the British monarch is also head of state': 0.13,
#  'who invented the python programming language': 0.09,
#  'wonders of the ancient world': 0.1,
#  'boroughs of New York City': 0.12,
#  'Branches of the US military': 0.32,
#  'continents in the world': 0.13,
#  'degrees of Eastern Orthodox monasticism': 0.06,
#  'Carriers that Blackberry makes phones for.': 0.31,
#  'Campuses of Indiana University.': 0.23,
#  'Donors to the Home Depot Foundation.': 0.0,
#  'Airlines that Air Canada has code share flights with.': 0.17,
#  'Authors awarded an Anthony Award at Bouchercon in 2007.': 0.08,
#  'Universities that are members of the SEC conference for football.': 0.17,
#  'Sponsors of the Mancuso quilt festivals.': 0.0,
#  'Members of the band Jefferson Airplane.': 0.03,
#  'Companies that John Hennessey serves on the board of.': 0.0,
#  'Winners of the ACM Athena award.': 0.0,
#  'Scotch whisky distilleries on the island of Islay.': 0.22,
#  'Professional sports teams in Philadelphia.': 0.31,
#  'Products of Medimmune, Inc.': 0.12,
#  'Organizations that award Nobel prizes.': 0.24,
#  'Airlines that currently use Boeing 747 planes.': 0.23,
#  'Members of The Beaux Arts Trio.': 0.01}
